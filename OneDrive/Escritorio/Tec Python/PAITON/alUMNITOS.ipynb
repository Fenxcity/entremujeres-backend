# %%
# %pip install pandas
import pandas as pd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: C:\Users\emiga\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# %pip install openpyxl
data = pd.read_excel('alumnos.xlsx')
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: C:\Users\emiga\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[105], line 2
#       1 get_ipython().run_line_magic('pip', 'install openpyxl')
# ----> 2 data = pd.read_excel('alumnos.xlsx')
#
# ...

# %%
print(data[(data['Carrera']=='Ingeniería en Sistemas') | (data['Carrera']=='Arquitectura')])
# Out:
#       ID                    Nombre     Género                 Carrera  \
# 0      1     Ulises Martínez Gómez   Femenino            Arquitectura
# 1      2        Valeria López Wong  Masculino  Ingeniería en Sistemas
# 6      7         Sofía Pérez López  Masculino            Arquitectura
# 9     10      Iván Quintana Torres  Masculino            Arquitectura
# 10    11          Iván López Pérez   Femenino            Arquitectura
# 18    19    Laura Sánchez Quintana  Masculino            Arquitectura
# 25    26           Laura Wong Wong   Femenino  Ingeniería en Sistemas
# 26    27   Zaira Martínez Quintana  Masculino            Arquitectura
# 29    30   Manuel Hernández Ortega   Femenino  Ingeniería en Sistemas
# 30    31        Jessica Wong Yáñez  Masculino            Arquitectura
# 31    32    Sofía Hernández Torres  Masculino  Ingeniería en Sistemas
# 39    40        Iván Sánchez Pérez   Femenino            Arquitectura
# ...

# %%
print(data[(data['Calificación Promedio']>8.5) & (data['Semestre']>=8)])
# Out:
#       ID                    Nombre     Género                     Carrera  \
# 18    19    Laura Sánchez Quintana  Masculino                Arquitectura
# 19    20        Ximena Yáñez López  Masculino                    Medicina
# 27    28  Fernanda Ramírez Xochitl  Masculino  Administración de Empresas
# 35    36        Oscar Torres López  Masculino                  Contaduría
# 55    56     Oscar Xochitl Xochitl  Masculino            Ingeniería Civil
# 65    66     Nadia Hernández Pérez   Femenino              Diseño Gráfico
# 74    75      Oscar Ramírez Urbina  Masculino               Mercadotecnia
# 81    82        Hilda Xochitl Vega   Femenino      Ingeniería en Sistemas
# 92    93  Patricia López Hernández  Masculino                    Medicina
# 99   100     Zaira Sánchez Sánchez   Femenino  Administración de Empresas
# 102  103   Yahir Ramírez Hernández  Masculino                  Contaduría
# 117  118      Alejandro Núñez Wong  Masculino  Administración de Empresas
# ...
